# %%
from neo4j import GraphDatabase
import json
from neo4j import GraphDatabase
import csv

# %%
uri = "bolt://localhost:7687"
username = "neo4j"
password = "12345678"

# Function to insert the data from CSV into Neo4j
def insert_data(tx, data):
    query = """
    CREATE (hero:Superhero {
        _id: $id,
        name: $name,
        powerstats: {
            intelligence: $intelligence,
            strength: $strength,
            speed: $speed,
            durability: $durability,
            power: $power,
            combat: $combat
        },
        biography: {
            full_name: $full_name,
            alter_egos: $alter_egos,
            aliases: $aliases,
            place_of_birth: $place_of_birth,
            first_appearance: $first_appearance,
            publisher: $publisher,
            alignment: $alignment
        },
        appearance: {
            gender: $gender,
            race: $race,
            height: $height,
            weight: $weight,
            eye_color: $eye_color,
            hair_color: $hair_color
        },
        work: {
            occupation: $occupation,
            base: $base
        },
        connections: {
            group_affiliation: $group_affiliation,
            relatives: $relatives
        },
        image: {
            url: $url
        }
    })
    """
    tx.run(query, **data)

# Load data from CSV
csv_file_path = 'superheroes.csv'

with open(csv_file_path, mode='r', encoding='utf-8') as csv_file:
    csv_reader = csv.DictReader(csv_file)
    for row in csv_reader:
        data = {
            'id': row['_id'],
            'name': row['name'],
            'intelligence': row['powerstats.intelligence'],
            'strength': row['powerstats.strength'],
            'speed': row['powerstats.speed'],
            'durability': row['powerstats.durability'],
            'power': row['powerstats.power'],
            'combat': row['powerstats.combat'],
            'full_name': row['biography.full-name'],
            'alter_egos': row['biography.alter-egos'],
            'aliases': row['biography.aliases'],
            'place_of_birth': row['biography.place-of-birth'],
            'first_appearance': row['biography.first-appearance'],
            'publisher': row['biography.publisher'],
            'alignment': row['biography.alignment'],
            'gender': row['appearance.gender'],
            'race': row['appearance.race'],
            'height': row['appearance.height'],
            'weight': row['appearance.weight'],
            'eye_color': row['appearance.eye-color'],
            'hair_color': row['appearance.hair-color'],
            'occupation': row['work.occupation'],
            'base': row['work.base'],
            'group_affiliation': row['connections.group-affiliation'],
            'relatives': row['connections.relatives'],
            'url': row['image.url']
        }

        # Establish connection to the Neo4j database and insert data
        driver = GraphDatabase.driver(uri, auth=(username, password))
        with driver.session() as session:
            session.write_transaction(insert_data, data)
# Out:
# C:\Users\santi\AppData\Local\Temp\ipykernel_25468\2310679703.py:89: DeprecationWarning: write_transaction has been renamed to execute_write
#   session.write_transaction(insert_data, data)
# Transaction failed and will be retried in 1.0809167010175393s (Database 'neo4j' is unavailable.)
# Transaction failed and will be retried in 1.9972235914775551s (Database 'neo4j' is unavailable.)
# Transaction failed and will be retried in 4.2649387351403245s (Database 'neo4j' is unavailable.)
# Transaction failed and will be retried in 9.49673952805327s (Database 'neo4j' is unavailable.)
# Transaction failed and will be retried in 16.749485165442024s (Database 'neo4j' is unavailable.)
# ---------------------------------------------------------------------------
# TransientError                            Traceback (most recent call last)
# Untitled-1.ipynb Cell 2 line 8
#      <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#W0sdW50aXRsZWQ%3D?line=86'>87</a> driver = GraphDatabase.driver(uri, auth=(username, password))
#      <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#W0sdW50aXRsZWQ%3D?line=87'>88</a> with driver.session() as session:
# ---> <a href='vscode-notebook-cell:Untitled-1.ipynb?jupyter-notebook#W0sdW50aXRsZWQ%3D?line=88'>89</a>     session.write_transaction(insert_data, data)
#
# File c:\Users\santi\anaconda3\envs\sparkenv\Lib\site-packages\neo4j\_meta.py:213, in _make_warning_decorator.<locals>.decorator.<locals>.inner(*args, **kwargs)
#     210 @wraps(f)
#     211 def inner(*args, **kwargs):
#     212     warning_func(message, stack_level=2)
# --> 213     return f(*args, **kwargs)
#
# File c:\Users\santi\anaconda3\envs\sparkenv\Lib\site-packages\neo4j\_sync\work\session.py:789, in Session.write_transaction(self, transaction_function, *args, **kwargs)
#     756 @deprecated("write_transaction has been renamed to execute_write")
#     757 def write_transaction(
#     758     self,
#    (...)
#     762     *args: _P.args,  **kwargs: _P.kwargs
#     763 ) -> _R:
#     764     """Execute a unit of work in a managed write transaction.
#     765
#     766     .. note::
#    (...)
#     787         Method was renamed to :meth:`.execute_write`.
#     788     """
# --> 789     return self._run_transaction(
#     790         WRITE_ACCESS, TelemetryAPI.TX_FUNC,
#     791         transaction_function, args, kwargs
#     792     )
#
# File c:\Users\santi\anaconda3\envs\sparkenv\Lib\site-packages\neo4j\_sync\work\session.py:584, in Session._run_transaction(self, access_mode, api, transaction_function, args, kwargs)
#     581         raise
#     583 if errors:
# --> 584     raise errors[-1]
#     585 else:
#     586     raise ServiceUnavailable("Transaction failed")
#
# File c:\Users\santi\anaconda3\envs\sparkenv\Lib\site-packages\neo4j\_sync\work\session.py:539, in Session._run_transaction(self, access_mode, api, transaction_function, args, kwargs)
#     537 while True:
#     538     try:
# --> 539         self._open_transaction(
#     540             tx_cls=ManagedTransaction,
#     541             api=None if telemetry_sent else api,
#     542             access_mode=access_mode, metadata=metadata,
#     543             timeout=timeout, api_success_cb=api_success_cb,
#     544         )
#     545         assert isinstance(self._transaction, ManagedTransaction)
#     546         tx = self._transaction
#
# File c:\Users\santi\anaconda3\envs\sparkenv\Lib\site-packages\neo4j\_sync\work\session.py:431, in Session._open_transaction(self, tx_cls, access_mode, api, metadata, timeout, api_success_cb)
#     424 self._transaction = tx_cls(
#     425     self._connection, self._config.fetch_size,
#     426     self._transaction_closed_handler,
#     427     self._transaction_error_handler,
#     428     self._transaction_cancel_handler
#     429 )
#     430 bookmarks = self._get_bookmarks()
# --> 431 self._transaction._begin(
#     432     self._config.database, self._config.impersonated_user,
#     433     bookmarks, access_mode, metadata, timeout,
#     434     self._config.notifications_min_severity,
#     435     self._config.notifications_disabled_categories,
#     436     pipelined=self._pipelined_begin
#     437 )
#
# File c:\Users\santi\anaconda3\envs\sparkenv\Lib\site-packages\neo4j\_sync\work\transaction.py:88, in TransactionBase._begin(self, database, imp_user, bookmarks, access_mode, metadata, timeout, notifications_min_severity, notifications_disabled_categories, pipelined)
#      86 if not pipelined:
#      87     self._error_handling_connection.send_all()
# ---> 88     self._error_handling_connection.fetch_all()
#
# File c:\Users\santi\anaconda3\envs\sparkenv\Lib\site-packages\neo4j\_sync\io\_common.py:180, in ConnectionErrorHandler.__getattr__.<locals>.outer.<locals>.inner(*args, **kwargs)
#     178 def inner(*args, **kwargs):
#     179     try:
# --> 180         func(*args, **kwargs)
#     181     except (Neo4jError, ServiceUnavailable, SessionExpired) as exc:
#     182         assert not asyncio.iscoroutinefunction(self.__on_error)
#
# File c:\Users\santi\anaconda3\envs\sparkenv\Lib\site-packages\neo4j\_sync\io\_bolt.py:865, in Bolt.fetch_all(self)
#     863 response = self.responses[0]
#     864 while not response.complete:
# --> 865     detail_delta, summary_delta = self.fetch_message()
#     866     detail_count += detail_delta
#     867     summary_count += summary_delta
#
# File c:\Users\santi\anaconda3\envs\sparkenv\Lib\site-packages\neo4j\_sync\io\_bolt.py:851, in Bolt.fetch_message(self)
#     847 # Receive exactly one message
#     848 tag, fields = self.inbox.pop(
#     849     hydration_hooks=self.responses[0].hydration_hooks
#     850 )
# --> 851 res = self._process_message(tag, fields)
#     852 self.idle_since = perf_counter()
#     853 return res
#
# File c:\Users\santi\anaconda3\envs\sparkenv\Lib\site-packages\neo4j\_sync\io\_bolt3.py:452, in Bolt3._process_message(self, tag, fields)
#     450 self._server_state_manager.state = BoltStates.FAILED
#     451 try:
# --> 452     response.on_failure(summary_metadata or {})
#     453 except (ServiceUnavailable, DatabaseUnavailable):
#     454     if self.pool:
#
# File c:\Users\santi\anaconda3\envs\sparkenv\Lib\site-packages\neo4j\_sync\io\_common.py:247, in Response.on_failure(self, metadata)
#     245 handler = self.handlers.get("on_summary")
#     246 Util.callback(handler)
# --> 247 raise Neo4jError.hydrate(**metadata)
#
# TransientError: {code: Neo.TransientError.Database.DatabaseUnavailable} {message: Database 'neo4j' is unavailable.}
